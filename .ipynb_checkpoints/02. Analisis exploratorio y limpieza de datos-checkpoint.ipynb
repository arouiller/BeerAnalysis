# %% [markdown]
# https://www.kaggle.com/datasets/thedevastator/1-5-million-beer-reviews-from-beer-advocate?select=beer_reviews.csv

# %% [markdown]
# # Iniciando la aventura

# %% [markdown]
# ## Importando paquetes necesarios

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import alejandro_chart_utils as acu

# %% [markdown]
# ## Lectura de los datos iniciales

# %%
file_dataset_inicial = 'dataset/beer_reviews.csv'

df = pd.read_csv(file_dataset_inicial)
df.drop(columns=['index'], inplace=True)
df.head(5)
# Out:
#    brewery_id             brewery_name  review_time  review_overall
# 0       10325          Vecchio Birraio   1234817823             1.5  \
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename
# 0           2.0                2.5            stcules  \
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste
# 0                      Hefeweizen            1.5           1.5  \
# 1              English Strong Ale            3.0           3.0
# 2          Foreign / Export Stout            3.0           3.0
# 3                 German Pilsener            2.5           3.0
# 4  American Double / Imperial IPA            4.0           4.5
#
#                 beer_name  beer_abv  beer_beerid
# 0            Sausa Weizen       5.0        47986
# 1                Red Moon       6.2        48213
# 2  Black Horse Black Beer       6.5        48215
# 3              Sausa Pils       5.0        47969
# 4           Cauldron DIPA       7.7        64883

# %% [markdown]
# ## Entendiendo nuestros datos

# %% [markdown]
# ### ¿Qué significa cada campo?
# 1. beer_beerid
# 1. beer_name
# 1. brewery_id
# 1. brewery_name
# 1. beer_style
# 1. beer_abv
# 1. review_profilename
# 1. review_time
# 1. review_overall
# 1. review_aroma
# 1. review_appearance
# 1. review_palate
# 1. review_taste

# %%
df = df.loc[:, ['beer_beerid','beer_name', 'brewery_id','brewery_name', 'beer_style','beer_abv', 'review_profilename','review_time','review_overall','review_aroma','review_appearance','review_palate','review_taste']]
df.head(5)
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv review_profilename  review_time
# 0                      Hefeweizen       5.0            stcules   1234817823  \
# 1              English Strong Ale       6.2            stcules   1235915097
# 2          Foreign / Export Stout       6.5            stcules   1235916604
# 3                 German Pilsener       5.0            stcules   1234725145
# 4  American Double / Imperial IPA       7.7     johnmichaelsen   1293735206
#
#    review_overall  review_aroma  review_appearance  review_palate
# 0             1.5           2.0                2.5            1.5  \
# 1             3.0           2.5                3.0            3.0
# 2             3.0           2.5                3.0            3.0
# 3             3.0           3.0                3.5            2.5
# 4             4.0           4.5                4.0            4.0
#
#    review_taste
# 0           1.5
# 1           3.0
# 2           3.0
# 3           3.0
# 4           4.5

# %% [markdown]
# ### Número de reseñas

# %%
len(df)
# Out:
# 1586614

# %% [markdown]
# ## Trabajando con múltiples reseñas

# %% [markdown]
# #### ¿Existen usuarios que hayan hecho más de un review a una misma cerveza?

# %%
df_resenias = df[['beer_beerid', 'review_profilename', 'review_time']].copy().drop_duplicates()
df_resenias.groupby(['beer_beerid', 'review_profilename'])['review_time'].size().reset_index(name='counts').sort_values(by=['counts'], ascending=False)
# Out:
#          beer_beerid review_profilename  counts
# 1259360        44713         AgentMunky       4
# 808899         15881           Kegatron       4
# 773428         12896        BretSikkink       4
# 809231         15881            Tucquan       4
# 356604          1543             glid02       4
# ...              ...                ...     ...
# 526952          3123         sketchpunx       1
# 526951          3123            scootny       1
# 526950          3123      santoslhalper       1
# 526949          3123             saccro       1
# 1571479        77317          seanwhite       1
#
# [1571480 rows x 3 columns]

# %% [markdown]
# #### ¿Qué hacemos cuando un usuario realiza más de una reseña? ¿Qué estrategias podemos utilizar?

# %% [markdown]
# 1. ¿Nos quedamos con todas las reseña que hizo?
# 1. ¿Generamos un promedio sobre las reseña que hizo?
# 1. ¿Nos quedamos con la primera reseña?
# 1. ¿Nos quedamos con la última reseña?
#
# ¿Cuál son los pros y los contras de cada estrategia?

# %% [markdown]
# #### Estrategia elegida: quedarnos con la última reseña de cada usuario

# %%
idx = df.groupby(['beer_beerid', 'review_profilename'])['review_time'].transform(max) == df['review_time']
df_resenias_unicas = df[idx]
df_resenias_unicas.head(5)
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv review_profilename  review_time
# 0                      Hefeweizen       5.0            stcules   1234817823  \
# 1              English Strong Ale       6.2            stcules   1235915097
# 2          Foreign / Export Stout       6.5            stcules   1235916604
# 3                 German Pilsener       5.0            stcules   1234725145
# 4  American Double / Imperial IPA       7.7     johnmichaelsen   1293735206
#
#    review_overall  review_aroma  review_appearance  review_palate
# 0             1.5           2.0                2.5            1.5  \
# 1             3.0           2.5                3.0            3.0
# 2             3.0           2.5                3.0            3.0
# 3             3.0           3.0                3.5            2.5
# 4             4.0           4.5                4.0            4.0
#
#    review_taste
# 0           1.5
# 1           3.0
# 2           3.0
# 3           3.0
# 4           4.5

# %% [markdown]
# #### ¿Cómo afecta al dataset quedarnos con una única reseña por usuario?

# %%
[
    ['Numero original de reseñas', len(df)],
    ['Numero de reseñas unicas', len(df_resenias_unicas)], 
    ['Numero de reseñas eliminadas', len(df) - len(df_resenias_unicas)],
    ['% de perdida de reseñas', (len(df) - len(df_resenias_unicas))/len(df)*100]
]
# Out:
# [['Numero original de reseñas', 1586614],
#  ['Numero de reseñas unicas', 1571487],
#  ['Numero de reseñas eliminadas', 15127],
#  ['% de perdida de reseñas', 0.9534139998764666]]

# %% [markdown]
# #### Guardamos el nuevo dataset

# %%
file_resenias_unicas = 'dataset/cervezas_resenias_unicas.csv'

# %%
df_resenias_unicas.to_csv(file_resenias_unicas, index=False)
df = df_resenias_unicas

# %%
df = pd.read_csv(file_resenias_unicas)
df.head(5)
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv review_profilename  review_time
# 0                      Hefeweizen       5.0            stcules   1234817823  \
# 1              English Strong Ale       6.2            stcules   1235915097
# 2          Foreign / Export Stout       6.5            stcules   1235916604
# 3                 German Pilsener       5.0            stcules   1234725145
# 4  American Double / Imperial IPA       7.7     johnmichaelsen   1293735206
#
#    review_overall  review_aroma  review_appearance  review_palate
# 0             1.5           2.0                2.5            1.5  \
# 1             3.0           2.5                3.0            3.0
# 2             3.0           2.5                3.0            3.0
# 3             3.0           3.0                3.5            2.5
# 4             4.0           4.5                4.0            4.0
#
#    review_taste
# 0           1.5
# 1           3.0
# 2           3.0
# 3           3.0
# 4           4.5

# %% [markdown]
# ### ¿Cuántas cervezas tenemos?

# %%
df_cervezas = df.loc[:, ['beer_beerid','beer_name','brewery_id','brewery_name','beer_style','beer_abv']].drop_duplicates()
[
    ['Total de cervezas', len(df_cervezas)]
]
# Out:
# [['Total de cervezas', 66051]]

# %%
file_cervezas_unicas = 'dataset/cervezas_unicas.csv'

# %%
df_cervezas.to_csv(file_cervezas_unicas, index=False)

# %% [markdown]
# ## Primer análisis visual de las puntuaciones y el contenido alcoholico

# %% [markdown]
# #### ¿Existen valores nulos?

# %%
df.loc[:, ['review_overall', 'review_aroma', 'review_appearance', 'review_palate', 'review_taste']].isna().sum()
# Out:
# review_overall       0
# review_aroma         0
# review_appearance    0
# review_palate        0
# review_taste         0
# dtype: int64

# %%
df_cervezas.loc[:, ['beer_abv']].isna().sum()
# Out:
# beer_abv    17040
# dtype: int64

# %% [markdown]
# #### Overall review

# %%
acu.plot_boxplot_violin(df['review_overall'], 'Overal review')

# %% [markdown]
# #### Aroma review

# %%
acu.plot_boxplot_violin(df['review_aroma'], 'Aroma review')

# %% [markdown]
# #### Appearance review

# %%
acu.plot_boxplot_violin(df['review_appearance'], 'Appearance review')

# %% [markdown]
# #### Palate review

# %%
acu.plot_boxplot_violin(df['review_palate'], 'Palate review')

# %% [markdown]
# #### Taste review

# %%
acu.plot_boxplot_violin(df['review_taste'], 'Taste review')

# %% [markdown]
# #### Alcohol by volume

# %%
acu.plot_boxplot_violin(df_cervezas['beer_abv'], 'Alcohol by volume')

# %% [markdown]
# El análisis del abv no es correcto, ya que tenemos N observaciones para cada cerveza

# %% [markdown]
# ## Generando agrupación de datos por cerveza

# %% [markdown]
# #### Transformando el review time a fecha

# %%
pd.options.mode.chained_assignment = None 
df['review_date'] = pd.to_datetime(df['review_time'], unit='s').dt.date
df.head(5)
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv review_profilename  review_time
# 0                      Hefeweizen       5.0            stcules   1234817823  \
# 1              English Strong Ale       6.2            stcules   1235915097
# 2          Foreign / Export Stout       6.5            stcules   1235916604
# 3                 German Pilsener       5.0            stcules   1234725145
# 4  American Double / Imperial IPA       7.7     johnmichaelsen   1293735206
#
#    review_overall  review_aroma  review_appearance  review_palate
# 0             1.5           2.0                2.5            1.5  \
# 1             3.0           2.5                3.0            3.0
# 2             3.0           2.5                3.0            3.0
# 3             3.0           3.0                3.5            2.5
# 4             4.0           4.5                4.0            4.0
#
#    review_taste review_date
# 0           1.5  2009-02-16
# 1           3.0  2009-03-01
# 2           3.0  2009-03-01
# 3           3.0  2009-02-15
# 4           4.5  2010-12-30

# %% [markdown]
# #### Generando un dataset de valores unicos por cerveza

# %%
def q1(x):
    return x.quantile(0.25)

def q2(x):
    return x.quantile(0.50)

def q3(x):
    return x.quantile(0.75)


df_cervezas_unicas_resumen_valores = df.groupby(['beer_beerid']).agg(
    #review_overall
    #review_overall_q1 = ('review_overall', q1),
    #review_overall_q2 = ('review_overall', q2),
    #review_overall_q3 = ('review_overall', q3),
    review_overall = ('review_overall', 'mean'),
    
    #review_aroma
    #review_aroma_q1 = ('review_aroma', q1),
    #review_aroma_q2 = ('review_aroma', q2),
    #review_aroma_q3 = ('review_aroma', q3),
    review_aroma = ('review_aroma', 'mean'),
    
    #review_appearance
    #review_appearance_q1 = ('review_appearance', q1),
    #review_appearance_q2 = ('review_appearance', q2),
    #review_appearance_q3 = ('review_appearance', q3),
    review_appearance = ('review_appearance', 'mean'),
    
    #review_palate
    #review_palate_q1 = ('review_palate', q1),
    #review_palate_q2 = ('review_palate', q2),
    #review_palate_q3 = ('review_palate', q3),
    review_palate = ('review_palate', 'mean'),
    
    #review_taste
    #review_taste_q1 = ('review_taste', q1),
    #review_taste_q2 = ('review_taste', q2),
    #review_taste_q3 = ('review_taste', q3),
    review_taste = ('review_taste', 'mean'),
    
    #review_time
    cantidad_revisiones = ('review_time', 'nunique'),
    
    #review_date
    revision_primera = ('review_date', np.min),
    revision_ultima = ('review_date', np.max)
).reset_index()
    
max_fecha = max(df['review_date'])

df_cervezas_unicas_resumen_valores['edad'] = ((max_fecha - df_cervezas_unicas_resumen_valores['revision_primera']) / np.timedelta64(1, 'Y')) + 1
df_cervezas_unicas_resumen_valores = df_cervezas_unicas_resumen_valores.astype({'edad':'int'})

df_cervezas_unicas_resumen_valores['disponibilidad'] = ((df_cervezas_unicas_resumen_valores['revision_ultima'] - df_cervezas_unicas_resumen_valores['revision_primera']) / np.timedelta64(1, 'Y'))+1
df_cervezas_unicas_resumen_valores = df_cervezas_unicas_resumen_valores.astype({'disponibilidad':'int'})

df_cervezas_unicas_resumen_valores.head()
# Out:
#    beer_beerid  review_overall  review_aroma  review_appearance
# 0            3        4.166667      4.000000           3.833333  \
# 1            4        3.700000      3.800000           3.950000
# 2            5        3.554762      3.208333           3.488095
# 3            6        3.707807      3.515499           3.839839
# 4            7        3.269466      3.177099           3.250382
#
#    review_palate  review_taste  cantidad_revisiones revision_primera
# 0       4.166667      4.166667                    3       2002-04-17  \
# 1       3.700000      3.450000                   10       2002-04-05
# 2       3.323810      3.342857                  420       2001-07-08
# 3       3.513777      3.644087                  871       2001-03-02
# 4       3.107634      3.101527                  655       2001-10-19
#
#   revision_ultima  edad  disponibilidad
# 0      2003-03-17    10               1
# 1      2005-03-21    10               3
# 2      2012-01-01    11              11
# 3      2012-01-02    11              11
# 4      2011-12-31    11              11

# %% [markdown]
# #### Agregamos los datos de las cervezas (nombre, abv, etc.)

# %%
df_cervezas_unicas_resumen_valores = pd.merge(df_cervezas, df_cervezas_unicas_resumen_valores, on='beer_beerid')
df_cervezas_unicas_resumen_valores.head()
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv  review_overall  review_aroma
# 0                      Hefeweizen       5.0             1.5           2.0  \
# 1              English Strong Ale       6.2             3.0           2.5
# 2          Foreign / Export Stout       6.5             3.0           2.5
# 3                 German Pilsener       5.0             3.0           3.0
# 4  American Double / Imperial IPA       7.7             4.0           4.5
#
#    review_appearance  review_palate  review_taste  cantidad_revisiones
# 0                2.5            1.5           1.5                    1  \
# 1                3.0            3.0           3.0                    1
# 2                3.0            3.0           3.0                    1
# 3                3.5            2.5           3.0                    1
# 4                4.0            4.0           4.5                    1
#
#   revision_primera revision_ultima  edad  disponibilidad
# 0       2009-02-16      2009-02-16     3               1
# 1       2009-03-01      2009-03-01     3               1
# 2       2009-03-01      2009-03-01     3               1
# 3       2009-02-15      2009-02-15     3               1
# 4       2010-12-30      2010-12-30     2               1

# %%
file_cervezas_unicas_resumen_valores = 'dataset/cervezas_unicas_resumen_valores.csv'

df_cervezas_unicas_resumen_valores.to_csv(file_cervezas_unicas_resumen_valores, index=False)
df = df_cervezas_unicas_resumen_valores

df.head()
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv  review_overall  review_aroma
# 0                      Hefeweizen       5.0             1.5           2.0  \
# 1              English Strong Ale       6.2             3.0           2.5
# 2          Foreign / Export Stout       6.5             3.0           2.5
# 3                 German Pilsener       5.0             3.0           3.0
# 4  American Double / Imperial IPA       7.7             4.0           4.5
#
#    review_appearance  review_palate  review_taste  cantidad_revisiones
# 0                2.5            1.5           1.5                    1  \
# 1                3.0            3.0           3.0                    1
# 2                3.0            3.0           3.0                    1
# 3                3.5            2.5           3.0                    1
# 4                4.0            4.0           4.5                    1
#
#   revision_primera revision_ultima  edad  disponibilidad
# 0       2009-02-16      2009-02-16     3               1
# 1       2009-03-01      2009-03-01     3               1
# 2       2009-03-01      2009-03-01     3               1
# 3       2009-02-15      2009-02-15     3               1
# 4       2010-12-30      2010-12-30     2               1

# %% [markdown]
# #### Media: Overall review

# %%
acu.plot_boxplot_violin(df['review_overall'], 'Media: Overall review')

# %% [markdown]
# #### Media: Aroma review

# %%
acu.plot_boxplot_violin(df['review_aroma'], 'Media: Aroma review')

# %% [markdown]
# #### Media: Appearance review

# %%
acu.plot_boxplot_violin(df['review_appearance'], 'Media: Appearance review')

# %% [markdown]
# #### Media: Palate review

# %%
acu.plot_boxplot_violin(df['review_palate'], 'Media: Palate review')

# %% [markdown]
# #### Media: Taste review

# %%
acu.plot_boxplot_violin(df['review_taste'], 'Media: Taste review')

# %% [markdown]
# #### Cantidad de revisiones

# %%
acu.plot_boxplot_violin(df['cantidad_revisiones'], 'Cantidad de revisiones')

# %% [markdown]
# #### Alcohol by volume

# %%
acu.plot_boxplot_violin(df['beer_abv'], 'Alcohol by volume')

# %% [markdown]
# #### Edad

# %%
acu.plot_boxplot_violin(df['edad'], 'Edad')

# %% [markdown]
# #### Disponibilidad

# %%
acu.plot_boxplot_violin(df['disponibilidad'],  'Disponibilidad')
