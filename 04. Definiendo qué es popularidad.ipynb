# %% [markdown]
# # 04. Definiendo qué es la popularidad

# %% [markdown]
# ### Algunas cosas para leer
#
# #### ¿Qué es un boxplot?
# https://datavizcatalogue.com/ES/metodos/diagrama_cajas_y_bigotes.html
#
# #### ¿Qué es un diagrama de violín?
# https://datavizcatalogue.com/ES/metodos/diagrama_de_violin.html

# %% [markdown]
# ## Importamos paquetes necesarios

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

import chart_utils as acu

# %% [markdown]
# ## ¿Qué hace popular a una cerveza?

# %% [markdown]
# ### Análisis general de la cantidad de revisiones

# %%
file_cervezas_unicas_resumen_valores = 'dataset/cervezas_unicas_resumen_valores.csv'

df = pd.read_csv(file_cervezas_unicas_resumen_valores)
df.head()
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv  review_overall  review_aroma
# 0                      Hefeweizen       5.0             1.5           2.0  \
# 1              English Strong Ale       6.2             3.0           2.5
# 2          Foreign / Export Stout       6.5             3.0           2.5
# 3                 German Pilsener       5.0             3.0           3.0
# 4  American Double / Imperial IPA       7.7             4.0           4.5
#
#    review_appearance  review_palate  review_taste  cantidad_revisiones
# 0                2.5            1.5           1.5                    1  \
# 1                3.0            3.0           3.0                    1
# 2                3.0            3.0           3.0                    1
# 3                3.5            2.5           3.0                    1
# 4                4.0            4.0           4.5                    1
#
#   revision_primera revision_ultima  edad  disponibilidad
# 0       2009-02-16      2009-02-16     3               1
# 1       2009-03-01      2009-03-01     3               1
# 2       2009-03-01      2009-03-01     3               1
# 3       2009-02-15      2009-02-15     3               1
# 4       2010-12-30      2010-12-30     2               1

# %%
acu.plot_boxplot_violin(df['cantidad_revisiones'],  'Cantidad de revisiones')

# %%
acu.plot_boxplot_violin(df['cantidad_revisiones'],  'Cantidad de revisiones', min_=-0, max_=40)

# %%
min_rev = min(df['cantidad_revisiones'])
q1_rev = np.quantile(df['cantidad_revisiones'], .25)
q2_rev = np.quantile(df['cantidad_revisiones'], .50)
q3_rev = np.quantile(df['cantidad_revisiones'], .75)
max_rev = max(df['cantidad_revisiones'])
ri_rev = q3_rev - q1_rev
pd.DataFrame(
    {
        'Titulo' : ['Minima cantidad de revisiones', 'Q1 (25%)', 'Q2 (50%)', 'Q3 (75%)','Bigote superior (Q3 + 1.5 RI)', 'Maxima cantidad de revisiones'],
        'Valores' : [
            str(min_rev),
            str(round(q1_rev, 3)),
            str(round(q2_rev, 3)),
            str(round(q3_rev, 3)),
            str(round(q3_rev + 1.5*ri_rev, 3)),
            str(max_rev)
        ]
    }
)
# Out:
#                           Titulo Valores
# 0  Minima cantidad de revisiones       1
# 1                       Q1 (25%)     1.0
# 2                       Q2 (50%)     3.0
# 3                       Q3 (75%)    10.0
# 4  Bigote superior (Q3 + 1.5 RI)    23.5
# 5  Maxima cantidad de revisiones    3206

# %%
cantidad_revisiones = df['cantidad_revisiones']

percentiles = []
valores = []
catas = []
nro_cervezas_por_encima = []
nro_cervezas_por_debajo = []
perc = []

total_cervezas = len(df)

for q in range(0,101, 1):
    p = q/100
    percentiles.append(q)
    
    quantile = np.quantile(cantidad_revisiones, p)
    valores.append(round(quantile, 2))
    
    nro_catas = quantile
    catas.append(nro_catas)
    
    cervezas_por_encima = len(df[df['cantidad_revisiones']>=nro_catas])
    cervezas_por_debajo = total_cervezas - cervezas_por_encima
    nro_cervezas_por_encima.append(str(cervezas_por_encima))
    nro_cervezas_por_debajo.append(str(cervezas_por_debajo))
    
    perc.append(str(round(cervezas_por_encima/total_cervezas * 100, 2)) + ' %')
    
tmp_df = pd.DataFrame(
    {
        'Percentil' : percentiles,
        'Catas' : catas,
        'Nro cervezas ↓' : nro_cervezas_por_debajo,
        'Nro cervezas ↑' : nro_cervezas_por_encima,
        '% ↑': perc
    }
)

with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(tmp_df)
# Out:
#      Percentil   Catas Nro cervezas ↓ Nro cervezas ↑      % ↑
# 0            0     1.0              0          49011  100.0 %
# 1            1     1.0              0          49011  100.0 %
# 2            2     1.0              0          49011  100.0 %
# 3            3     1.0              0          49011  100.0 %
# 4            4     1.0              0          49011  100.0 %
# 5            5     1.0              0          49011  100.0 %
# 6            6     1.0              0          49011  100.0 %
# 7            7     1.0              0          49011  100.0 %
# 8            8     1.0              0          49011  100.0 %
# 9            9     1.0              0          49011  100.0 %
# 10          10     1.0              0          49011  100.0 %
# 11          11     1.0              0          49011  100.0 %
# 12          12     1.0              0          49011  100.0 %
# 13          13     1.0              0          49011  100.0 %
# 14          14     1.0              0          49011  100.0 %
# 15          15     1.0              0          49011  100.0 %
# 16          16     1.0              0          49011  100.0 %
# 17          17     1.0              0          49011  100.0 %
# 18          18     1.0              0          49011  100.0 %
# 19          19     1.0              0          49011  100.0 %
# 20          20     1.0              0          49011  100.0 %
# 21          21     1.0              0          49011  100.0 %
# 22          22     1.0              0          49011  100.0 %
# 23          23     1.0              0          49011  100.0 %
# 24          24     1.0              0          49011  100.0 %
# 25          25     1.0              0          49011  100.0 %
# 26          26     1.0              0          49011  100.0 %
# 27          27     1.0              0          49011  100.0 %
# 28          28     1.0              0          49011  100.0 %
# 29          29     1.0              0          49011  100.0 %
# 30          30     1.0              0          49011  100.0 %
# 31          31     1.0              0          49011  100.0 %
# 32          32     2.0          15677          33334  68.01 %
# 33          33     2.0          15677          33334  68.01 %
# 34          34     2.0          15677          33334  68.01 %
# 35          35     2.0          15677          33334  68.01 %
# 36          36     2.0          15677          33334  68.01 %
# 37          37     2.0          15677          33334  68.01 %
# 38          38     2.0          15677          33334  68.01 %
# 39          39     2.0          15677          33334  68.01 %
# 40          40     2.0          15677          33334  68.01 %
# 41          41     2.0          15677          33334  68.01 %
# 42          42     2.0          15677          33334  68.01 %
# 43          43     2.0          15677          33334  68.01 %
# 44          44     2.0          15677          33334  68.01 %
# 45          45     2.0          15677          33334  68.01 %
# 46          46     2.0          15677          33334  68.01 %
# 47          47     3.0          22897          26114  53.28 %
# 48          48     3.0          22897          26114  53.28 %
# 49          49     3.0          22897          26114  53.28 %
# 50          50     3.0          22897          26114  53.28 %
# 51          51     3.0          22897          26114  53.28 %
# 52          52     3.0          22897          26114  53.28 %
# 53          53     3.0          22897          26114  53.28 %
# 54          54     3.0          22897          26114  53.28 %
# 55          55     3.0          22897          26114  53.28 %
# 56          56     4.0          27083          21928  44.74 %
# 57          57     4.0          27083          21928  44.74 %
# 58          58     4.0          27083          21928  44.74 %
# 59          59     4.0          27083          21928  44.74 %
# 60          60     4.0          27083          21928  44.74 %
# 61          61     5.0          29857          19154  39.08 %
# 62          62     5.0          29857          19154  39.08 %
# 63          63     5.0          29857          19154  39.08 %
# 64          64     5.0          29857          19154  39.08 %
# 65          65     6.0          31824          17187  35.07 %
# 66          66     6.0          31824          17187  35.07 %
# 67          67     6.0          31824          17187  35.07 %
# 68          68     7.0          33291          15720  32.07 %
# 69          69     7.0          33291          15720  32.07 %
# 70          70     7.0          33291          15720  32.07 %
# 71          71     8.0          34473          14538  29.66 %
# 72          72     8.0          34473          14538  29.66 %
# 73          73     9.0          35407          13604  27.76 %
# 74          74    10.0          36183          12828  26.17 %
# 75          75    10.0          36183          12828  26.17 %
# 76          76    11.0          36855          12156   24.8 %
# 77          77    12.0          37405          11606  23.68 %
# 78          78    13.0          37917          11094  22.64 %
# 79          79    14.0          38404          10607  21.64 %
# 80          80    16.0          39200           9811  20.02 %
# 81          81    17.0          39545           9466  19.31 %
# 82          82    19.0          40134           8877  18.11 %
# 83          83    21.0          40609           8402  17.14 %
# 84          84    23.0          41007           8004  16.33 %
# 85          85    26.0          41558           7453  15.21 %
# 86          86    29.0          42007           7004  14.29 %
# 87          87    33.0          42536           6475  13.21 %
# 88          88    38.0          43064           5947  12.13 %
# 89          89    44.0          43592           5419  11.06 %
# 90          90    51.0          44074           4937  10.07 %
# 91          91    59.0          44564           4447   9.07 %
# 92          92    70.0          45046           3965   8.09 %
# 93          93    85.0          45570           3441   7.02 %
# 94          94   105.0          46059           2952   6.02 %
# 95          95   134.0          46552           2459   5.02 %
# 96          96   173.0          47045           1966   4.01 %
# 97          97   239.0          47539           1472    3.0 %
# 98          98   340.0          48027            984   2.01 %
# 99          99   575.0          48519            492    1.0 %
# 100        100  3206.0          49010              1    0.0 %

# %%
round(tmp_df[tmp_df['Percentil'] == 95].Catas.values[0], 2)
# Out:
# 134.0

# %% [markdown]
# #### Asignamos la clase al dataset principal

# %%
cuantil_elegido = 95
umbral = tmp_df[tmp_df['Percentil'] == cuantil_elegido].Catas.values[0]

df_cervezas_unicas_resumen_valores_con_clase = df.copy()

df_cervezas_unicas_resumen_valores_con_clase['es_popular'] = np.where(
    df_cervezas_unicas_resumen_valores_con_clase['cantidad_revisiones']>umbral, 'SI', 'NO')

df_cervezas_unicas_resumen_valores_con_clase.head()
# Out:
#    beer_beerid               beer_name  brewery_id             brewery_name
# 0        47986            Sausa Weizen       10325          Vecchio Birraio  \
# 1        48213                Red Moon       10325          Vecchio Birraio
# 2        48215  Black Horse Black Beer       10325          Vecchio Birraio
# 3        47969              Sausa Pils       10325          Vecchio Birraio
# 4        64883           Cauldron DIPA        1075  Caldera Brewing Company
#
#                        beer_style  beer_abv  review_overall  review_aroma
# 0                      Hefeweizen       5.0             1.5           2.0  \
# 1              English Strong Ale       6.2             3.0           2.5
# 2          Foreign / Export Stout       6.5             3.0           2.5
# 3                 German Pilsener       5.0             3.0           3.0
# 4  American Double / Imperial IPA       7.7             4.0           4.5
#
#    review_appearance  review_palate  review_taste  cantidad_revisiones
# 0                2.5            1.5           1.5                    1  \
# 1                3.0            3.0           3.0                    1
# 2                3.0            3.0           3.0                    1
# 3                3.5            2.5           3.0                    1
# 4                4.0            4.0           4.5                    1
#
#   revision_primera revision_ultima  edad  disponibilidad es_popular
# 0       2009-02-16      2009-02-16     3               1         NO
# 1       2009-03-01      2009-03-01     3               1         NO
# 2       2009-03-01      2009-03-01     3               1         NO
# 3       2009-02-15      2009-02-15     3               1         NO
# 4       2010-12-30      2010-12-30     2               1         NO

# %%
df_cervezas_unicas_resumen_valores_con_clase.groupby(by=['es_popular']).size().reset_index(name='counts')
# Out:
#   es_popular  counts
# 0         NO   46552
# 1         SI    2459

# %%
file_cervezas_unicas_resumen_valores_con_clase = 'dataset/cervezas_unicas_resumen_valores_con_clase.csv'
df_cervezas_unicas_resumen_valores_con_clase.to_csv(file_cervezas_unicas_resumen_valores_con_clase, index=False)
